# %%
## to add two variable

def add(x,y): #x,y are the paramenters which can hold the actual value passed to the function
    return x+y #the add function add its returning addition x,y

# %%
add(3,9)  #fucntion call
# Out:
# 12

# %%
add(4,13487189)
# Out:
# 13487193

# %%
### addition

def add():
    a=int(input("enter a"))
    b=int(input("enter b"))
    print(a+b)

# %%
add()
# Out:
# enter a 48267867839
# enter b 296383
# 48268164222

# %%
### substraction

def sub():
     a=int(input("enter a"))
     b=int(input("enter b"))
     print(a-b)

# %%
sub()
# Out:
# enter a 6187461876876876
# enter b 13287682768678
# 6174174194108198

# %%
##  Write different functions for multiplication, substraction, division


def multiply(a, b):
    return a * b
    


def subtract(a, b):
    return a - b
   

def divide(a, b):
    
    return a / b

print(f"5 * 3 = {multiply(5, 3)}")
print(f"10 - 4 = {subtract(10, 4)}")
print(f"20 / 5 = {divide(20, 5)}")
# Out:
# 5 * 3 = 15
# 10 - 4 = 6
# 20 / 5 = 4.0

# %%
##  Write a function which will accept 2 numbers from used and return their division, floor division, modulus 

a=int(input("enter a"))
b=int(input("enter b"))

def divide(a,b):
    return a/b

def floor_divide(a,b):
    return a//b

def modules (a,b):
    return a%b

print(a/b)
print(a//b)
print(a%b)
# Out:
# enter a 100
# enter b 5
# 20.0
# 20
# 0

# %%
##  Write a function to find area of rectangle 

def calculate_area(length, width):
     l=int(input("enter l"))
     w=int(input("enter w"))

   
     area=l*w
     return area
calculate_area(100,50)
# Out:
# enter l 1000
# enter w 56
# 56000

# %%
## Write a function to find area of circle 



def calculate_circle_area(radius):
 
  if radius < 0:
    return false
  area = 3.14 * (radius ** 2)
  return area
calculate_circle_area(58)
# Out:
# 10562.960000000001

# %%
## Write a function to find even and odd numbers, take number as user input

def find_even_odd(number):
 
  if number % 2 == 0:
    return "Even"
  else:
    return "Odd"


  user_input_str = input("Enter a whole number: ")
  user_number = int(user_input_str)
find_even_odd(682)
# Out:
# 'Even'
