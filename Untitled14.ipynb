# %%
## Question 1.

num=int(input("enter a number"))
sum=0
temp=num
while temp>0:
    digit=temp%10
    sum += digit**3
    temp//=10
    if num==sum:
        print("amstring number")
    else:
        print("not amstrong number")

# %%
## Question 2.

s1=float(input("first side lenght"))
s2=float(input("second side lenght"))
s3=float(input("third side lenght"))

if s1<=0 or s2<=0 or s3<=0:
    print("lenght in positive")
    if not (s1+s2>s3 and s1+s3>s2 and s2+s3>s1):
        print("side not valid for triangle")
        if s1==s2 and s2==s3:
            print("equilateral triangle")
        elif s1==s2 and s2==s3 and s3==s1:
            print("isoscles trinagle")
        else:
            print("scalen triangle")

# %%
## Question 3.

x1=int(input("enter x1"))
x2=int(input("enter x2"))
y1=int(input("enter y1"))
y2-int(input("enter y2"))
m=0

a=(x2-x1)
b=(y2-y1)

if b==0:
    m=0
else:
    m=(b)/(a)

# %%
##Question 4.

r=float(input("enter radius"))
a=3.14*r*r
print("area of circle",a)
# Out:
# enter radius 7.5
# area of circle 176.625

# %%
##Question 5.

a=int(input("enter number"))
sum_even_digit=0
product_odd_digit=1

num_str=str(abs(a))
for i in num_str:
    a=int(digit_char)
    if a%2==0:
        sum_even_digit+=a
    else:
        produt_odd_digit+=a

# %%
## Question 8.


for i in range(100,1000):
    sum=0
    while(i>0):
        rem==i%10
        sum=sum=(rem*rem*rem)
        i=i//10
        if(sum==a):
            print(a,"amstrong number")

# %%
##Question .9


a=int(input("enter first number"))
b=int(input("enter second number"))

for i in range (a,b+1):
    if (i**(.5)==int(i**(.5))):
        print(i,end=",")
# Out:
# enter first number 2
# enter second number 24
# 4,9,16,

# %%
n=int(input("entr n"))

a=n
b=n+1
c=n+2

left_side=a**2 + b**2
right_side=c**2

left_side==right_side
# Out:
# entr n 3
# True
